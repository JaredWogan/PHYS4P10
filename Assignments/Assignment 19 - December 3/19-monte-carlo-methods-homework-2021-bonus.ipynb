# %% [markdown]
# # 19 Monte Carlo methods

# %% [markdown]
# ### Challenge: Make the spins face a random direction, and evolve the system by changing the direction of the spins.

# %%
from scripts_bonus import simulation

# %%
simulation(
    N=10,
    J=1,
    T=0.001
)

simulation(
    N=20,
    J=1,
    T=0.001
)

simulation(
    N=30,
    J=1,
    T=0.001
)

simulation(
    N=40,
    J=1,
    T=0.001
)

# %%
simulation(
    N=10,
    J=1,
    T=1
)

simulation(
    N=20,
    J=1,
    T=1
)

simulation(
    N=30,
    J=1,
    T=1
)

simulation(
    N=40,
    J=1,
    T=1
)
